# %% [markdown]
# # to get the current working directory

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Kalyani'

# %% [markdown]
# # to change the directory

# %%
os.chdir("C:/Users/kalyani/Desktop/data_sets")
os.getcwd()
# Out:
# 'C:\\Users\\kalyani\\Desktop\\data_sets'

# %% [markdown]
# # importing packages and read the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data1 = pd.read_csv("admission.csv")
data1
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %% [markdown]
# # to drop the column

# %%
data1 = data1.drop(['Serial No.'],axis=1)
data1
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# 5          330          115                  5  4.5   3.0  9.34         1
# 6          321          109                  3  3.0   4.0  8.20         1
# 7          308          101                  2  3.0   4.0  7.90         0
# 8          302          102                  1  2.0   1.5  8.00         0
# 9          323          108                  3  3.5   3.0  8.60         0
# 10         325          106                  3  3.5   4.0  8.40         1
# 11         327          111                  4  4.0   4.5  9.00         1
# ...

# %% [markdown]
# # to find the number of missing values

# %%
data1.apply(lambda x:
sum(x.isnull()),axis=0)
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# # there is no incomplete data

# %% [markdown]
# # inputs into the features and output into the label

# %%
features = data1.iloc[:,:-1].values
df1 = pd.DataFrame(features)
df1
# Out:
#          0      1    2    3    4     5    6
# 0    337.0  118.0  4.0  4.5  4.5  9.65  1.0
# 1    324.0  107.0  4.0  4.0  4.5  8.87  1.0
# 2    316.0  104.0  3.0  3.0  3.5  8.00  1.0
# 3    322.0  110.0  3.0  3.5  2.5  8.67  1.0
# 4    314.0  103.0  2.0  2.0  3.0  8.21  0.0
# 5    330.0  115.0  5.0  4.5  3.0  9.34  1.0
# 6    321.0  109.0  3.0  3.0  4.0  8.20  1.0
# 7    308.0  101.0  2.0  3.0  4.0  7.90  0.0
# 8    302.0  102.0  1.0  2.0  1.5  8.00  0.0
# 9    323.0  108.0  3.0  3.5  3.0  8.60  0.0
# 10   325.0  106.0  3.0  3.5  4.0  8.40  1.0
# 11   327.0  111.0  4.0  4.0  4.5  9.00  1.0
# 12   328.0  112.0  4.0  4.0  4.5  9.10  1.0
# 13   307.0  109.0  3.0  4.0  3.0  8.00  1.0
# 14   311.0  104.0  3.0  3.5  2.0  8.20  1.0
# 15   314.0  105.0  3.0  3.5  2.5  8.30  0.0
# 16   317.0  107.0  3.0  4.0  3.0  8.70  0.0
# 17   319.0  106.0  3.0  4.0  3.0  8.00  1.0
# 18   318.0  110.0  3.0  4.0  3.0  8.80  0.0
# 19   303.0  102.0  3.0  3.5  3.0  8.50  0.0
# ...

# %% [markdown]
# # To change the column names

# %%
df1.columns = ['GRE Score','TOEFL Score','University Rating','SOP','LOR ','CGPA','Research']
df1
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0        337.0        118.0                4.0  4.5   4.5  9.65       1.0
# 1        324.0        107.0                4.0  4.0   4.5  8.87       1.0
# 2        316.0        104.0                3.0  3.0   3.5  8.00       1.0
# 3        322.0        110.0                3.0  3.5   2.5  8.67       1.0
# 4        314.0        103.0                2.0  2.0   3.0  8.21       0.0
# 5        330.0        115.0                5.0  4.5   3.0  9.34       1.0
# 6        321.0        109.0                3.0  3.0   4.0  8.20       1.0
# 7        308.0        101.0                2.0  3.0   4.0  7.90       0.0
# 8        302.0        102.0                1.0  2.0   1.5  8.00       0.0
# 9        323.0        108.0                3.0  3.5   3.0  8.60       0.0
# 10       325.0        106.0                3.0  3.5   4.0  8.40       1.0
# 11       327.0        111.0                4.0  4.0   4.5  9.00       1.0
# ...

# %%
labels = data1.iloc[:,-1].values
df2 = pd.DataFrame(labels)
df2.columns = ['Chance of Admit ']
df2
# Out:
#      Chance of Admit
# 0                0.92
# 1                0.76
# 2                0.72
# 3                0.80
# 4                0.65
# 5                0.90
# 6                0.75
# 7                0.68
# 8                0.50
# 9                0.45
# 10               0.52
# 11               0.84
# 12               0.78
# 13               0.62
# 14               0.61
# 15               0.54
# 16               0.66
# 17               0.65
# 18               0.63
# 19               0.62
# 20               0.64
# 21               0.70
# 22               0.94
# 23               0.95
# 24               0.97
# 25               0.94
# 26               0.76
# 27               0.44
# 28               0.46
# 29               0.54
# ..                ...
# 470              0.87
# 471              0.64
# 472              0.90
# 473              0.67
# 474              0.67
# 475              0.59
# 476              0.62
# 477              0.65
# 478              0.71
# ...

# %%
gre = df1['GRE Score']
toefl = df1['TOEFL Score']
university_rating = df1['University Rating']
sop = df1['SOP']
lor = df1['LOR ']
cgpa = df1['CGPA']
research = df1['Research']
chance = df2['Chance of Admit ']

# %% [markdown]
# # correlation

# %%
data1.corr()
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.827200           0.635376  0.613498
# TOEFL Score         0.827200     1.000000           0.649799  0.644410
# University Rating   0.635376     0.649799           1.000000  0.728024
# SOP                 0.613498     0.644410           0.728024  1.000000
# LOR                 0.524679     0.541563           0.608651  0.663707
# CGPA                0.825878     0.810574           0.705254  0.712154
# Research            0.563398     0.467012           0.427047  0.408116
# Chance of Admit     0.810351     0.792228           0.690132  0.684137
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.524679  0.825878  0.563398          0.810351
# TOEFL Score        0.541563  0.810574  0.467012          0.792228
# University Rating  0.608651  0.705254  0.427047          0.690132
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ax = plt.plot(gre,chance,'o')
plt.ylabel("chance")
plt.xlabel("gre")
# Out:
# Text(0.5,0,'gre')

# %%
ax = plt.plot(toefl,chance,'o')
plt.ylabel("chance")
plt.xlabel("toefl")
# Out:
# Text(0.5,0,'toefl')

# %%
ax = plt.plot(university_rating,chance,'o')
plt.ylabel("chance")
plt.xlabel("university_rating")
# Out:
# Text(0.5,0,'university_rating')

# %%
ax = plt.plot(sop,chance,'o')
plt.ylabel("chance")
plt.xlabel("sop")
# Out:
# Text(0.5,0,'sop')

# %%
ax = plt.plot(lor,chance,'o')
plt.ylabel("chance")
plt.xlabel("lor")
# Out:
# Text(0.5,0,'lor')

# %%
ax = plt.plot(cgpa,chance,'o')
plt.ylabel("chance")
plt.xlabel("cgpa")
# Out:
# Text(0.5,0,'cgpa')

# %%
ax = plt.plot(research,chance,'o')
plt.ylabel("chance")
plt.xlabel("research")
# Out:
# Text(0.5,0,'research')

# %%
data1.boxplot(column = 'Chance of Admit ',by = 'GRE Score')

# %%
data1.boxplot(column = 'Chance of Admit ',by = 'TOEFL Score')

# %%
data1.boxplot(column = 'Chance of Admit ',by = 'University Rating')

# %%
data1.boxplot(column = 'Chance of Admit ',by = 'SOP')

# %%
data1.boxplot(column = 'Chance of Admit ',by = 'LOR ')

# %%
data1.boxplot(column = 'Chance of Admit ',by = 'LOR ')

# %%
data1.boxplot(column = 'Chance of Admit ',by = 'Research')

# %% [markdown]
# # seaborn map

# %%
import seaborn as sns
sns.pairplot(df1)

# %% [markdown]
# # dist plots

# %%
sns.distplot(data1["GRE Score"])
# Out:
# C:\Users\Kalyani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Kalyani\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(data1["TOEFL Score"])
# Out:
# C:\Users\Kalyani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Kalyani\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(data1["University Rating"])
# Out:
# C:\Users\Kalyani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Kalyani\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(data1["SOP"])
# Out:
# C:\Users\Kalyani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Kalyani\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(data1["LOR "])
# Out:
# C:\Users\Kalyani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Kalyani\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(data1["Research"])
# Out:
# C:\Users\Kalyani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Kalyani\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # heatmap

# %%
corr = data1.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels = corr.columns)

# %% [markdown]
# # stat models

# %% [markdown]
# # GRE ,CHANCE OF ADMIT

# %%
import statsmodels.api as sm
model1 = sm.OLS(gre,chance).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              GRE Score   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                 1.792e+04
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):               0.00
# Time:                        13:55:41   Log-Likelihood:                -2686.3
# No. Observations:                 500   AIC:                             5375.
# Df Residuals:                     499   BIC:                             5379.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # toefl score-chance of admit

# %%
model2 = sm.OLS(toefl,chance).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            TOEFL Score   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                 2.127e+04
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):               0.00
# Time:                        13:55:41   Log-Likelihood:                -2103.7
# No. Observations:                 500   AIC:                             4209.
# Df Residuals:                     499   BIC:                             4214.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # SOP - chance of admission

# %%
model3 = sm.OLS(sop,chance).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    SOP   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                 1.133e+04
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):               0.00
# Time:                        13:55:41   Log-Likelihood:                -546.80
# No. Observations:                 500   AIC:                             1096.
# Df Residuals:                     499   BIC:                             1100.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # LOR - chance of Admission

# %%
model4 = sm.OLS(lor,chance).fit()
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   LOR    R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                 1.233e+04
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):               0.00
# Time:                        13:55:42   Log-Likelihood:                -538.94
# No. Observations:                 500   AIC:                             1080.
# Df Residuals:                     499   BIC:                             1084.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # cgpa - chance of admission

# %%
model4 = sm.OLS(cgpa,chance).fit()
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   CGPA   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                 2.707e+04
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):               0.00
# Time:                        13:55:42   Log-Likelihood:                -782.22
# No. Observations:                 500   AIC:                             1566.
# Df Residuals:                     499   BIC:                             1571.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Split the data into Training set and Test set(80% - 20%)

# %% [markdown]
# # GRE SCORE - CHANCE OF ADMIT

# %%
X = df1['GRE Score']
Y = df2['Chance of Admit ']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2,random_state = 1)
X_test
# Out:
# 304    313.0
# 340    312.0
# 47     339.0
# 67     316.0
# 479    325.0
# 485    311.0
# 310    320.0
# 31     327.0
# 249    321.0
# 90     318.0
# 322    314.0
# 168    293.0
# 119    327.0
# 66     327.0
# 305    321.0
# 189    324.0
# 434    306.0
# 289    313.0
# 142    331.0
# 146    315.0
# 293    312.0
# 312    311.0
# 311    328.0
# 492    298.0
# 65     325.0
# 374    315.0
# 34     331.0
# 342    308.0
# 173    323.0
# 201    315.0
#        ...
# 323    305.0
# 324    315.0
# 147    326.0
# 29     310.0
# 107    338.0
# 463    304.0
# 495    332.0
# 425    323.0
# 250    320.0
# 135    314.0
# 260    327.0
# 117    290.0
# 187    335.0
# 415    327.0
# 165    322.0
# 223    308.0
# 444    324.0
# 285    331.0
# 491    297.0
# 476    304.0
# 477    309.0
# 480    321.0
# 417    316.0
# 6      321.0
# 422    322.0
# 11     327.0
# 192    322.0
# 92     298.0
# 221    316.0
# 110    305.0
# Name: GRE Score, Length: 100, dtype: float64

# %%
Y_train
# Out:
# 238    0.70
# 438    0.67
# 475    0.59
# 58     0.36
# 380    0.78
# 78     0.44
# 379    0.71
# 247    0.71
# 207    0.66
# 101    0.64
# 344    0.47
# 392    0.84
# 423    0.94
# 488    0.76
# 256    0.76
# 180    0.71
# 436    0.58
# 18     0.63
# 40     0.46
# 421    0.77
# 469    0.86
# 41     0.49
# 159    0.52
# 286    0.92
# 132    0.71
# 290    0.58
# 496    0.96
# 341    0.79
# 80     0.50
# 46     0.86
#        ...
# 68     0.68
# 50     0.76
# 398    0.67
# 413    0.49
# 156    0.70
# 252    0.71
# 395    0.82
# 468    0.81
# 402    0.78
# 357    0.68
# 254    0.85
# 276    0.89
# 178    0.72
# 281    0.80
# 390    0.64
# 237    0.86
# 71     0.96
# 460    0.77
# 129    0.92
# 144    0.80
# 448    0.80
# 335    0.83
# 133    0.79
# 203    0.97
# 393    0.77
# 255    0.79
# 72     0.93
# 396    0.84
# 235    0.88
# 37     0.58
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
X_test
# Out:
# 304    313.0
# 340    312.0
# 47     339.0
# 67     316.0
# 479    325.0
# 485    311.0
# 310    320.0
# 31     327.0
# 249    321.0
# 90     318.0
# 322    314.0
# 168    293.0
# 119    327.0
# 66     327.0
# 305    321.0
# 189    324.0
# 434    306.0
# 289    313.0
# 142    331.0
# 146    315.0
# 293    312.0
# 312    311.0
# 311    328.0
# 492    298.0
# 65     325.0
# 374    315.0
# 34     331.0
# 342    308.0
# 173    323.0
# 201    315.0
#        ...
# 323    305.0
# 324    315.0
# 147    326.0
# 29     310.0
# 107    338.0
# 463    304.0
# 495    332.0
# 425    323.0
# 250    320.0
# 135    314.0
# 260    327.0
# 117    290.0
# 187    335.0
# 415    327.0
# 165    322.0
# 223    308.0
# 444    324.0
# 285    331.0
# 491    297.0
# 476    304.0
# 477    309.0
# 480    321.0
# 417    316.0
# 6      321.0
# 422    322.0
# 11     327.0
# 192    322.0
# 92     298.0
# 221    316.0
# 110    305.0
# Name: GRE Score, Length: 100, dtype: float64

# %%
Y_test
# Out:
# 304    0.62
# 340    0.75
# 47     0.89
# 67     0.57
# 479    0.79
# 485    0.70
# 310    0.76
# 31     0.74
# 249    0.77
# 90     0.64
# 322    0.72
# 168    0.64
# 119    0.71
# 66     0.61
# 305    0.74
# 189    0.88
# 434    0.64
# 289    0.79
# 142    0.92
# 146    0.75
# 293    0.64
# 312    0.78
# 311    0.84
# 492    0.53
# 65     0.55
# 374    0.39
# 34     0.94
# 342    0.58
# 173    0.89
# 201    0.72
#        ...
# 323    0.62
# 324    0.67
# 147    0.83
# 29     0.54
# 107    0.91
# 463    0.57
# 495    0.87
# 425    0.92
# 250    0.74
# 135    0.82
# 260    0.87
# 117    0.45
# 187    0.93
# 415    0.76
# 165    0.78
# 223    0.71
# 444    0.92
# 285    0.93
# 491    0.54
# 476    0.62
# 477    0.65
# 480    0.80
# 417    0.52
# 6      0.75
# 422    0.73
# 11     0.84
# 192    0.86
# 92     0.34
# 221    0.75
# 110    0.61
# Name: Chance of Admit , Length: 100, dtype: float64

# %% [markdown]
# # linear regression with sklearn

# %%
X_train = X_train.values.reshape((-1,1))
X_train
# Out:
# array([[310.],
#        [318.],
#        [300.],
#        [300.],
#        [322.],
#        [296.],
#        [311.],
#        [311.],
#        [310.],
#        [312.],
#        [295.],
#        [326.],
#        [334.],
#        [322.],
#        [309.],
#        [300.],
#        [310.],
#        [318.],
#        [308.],
#        [321.],
#        [326.],
#        [316.],
#        [297.],
#        [336.],
#        [309.],
#        [307.],
#        [337.],
#        [326.],
#        [312.],
#        [329.],
#        [299.],
#        [301.],
#        [327.],
#        [340.],
#        [336.],
#        [326.],
#        [324.],
#        [310.],
#        [304.],
#        [296.],
#        [318.],
#        [329.],
#        [312.],
#        [300.],
#        [298.],
#        [311.],
#        [310.],
#        [304.],
#        [310.],
#        [334.],
#        [307.],
#        [307.],
#        [330.],
#        [307.],
#        [322.],
#        [326.],
#        [324.],
#        [322.],
# ...

# %%
from sklearn import linear_model as lm
model = lm.LinearRegression()
results = model.fit(X_train,Y_train)

# %% [markdown]
# # accuracy

# %%
accuracy = model.score(X_train,Y_train)
print('Accuracy of the model:',accuracy)
# Out:
# Accuracy of the model: 0.666157646389397

# %% [markdown]
# # Print coefficients

# %%
print('intercept',model.intercept_)
print('slope:',model.coef_)
# Out:
# intercept -2.4780912437049487
# slope: [0.01011923]

# %%
X_test = X_test.values.reshape((-1,1))
X_test
# Out:
# array([[313.],
#        [312.],
#        [339.],
#        [316.],
#        [325.],
#        [311.],
#        [320.],
#        [327.],
#        [321.],
#        [318.],
#        [314.],
#        [293.],
#        [327.],
#        [327.],
#        [321.],
#        [324.],
#        [306.],
#        [313.],
#        [331.],
#        [315.],
#        [312.],
#        [311.],
#        [328.],
#        [298.],
#        [325.],
#        [315.],
#        [331.],
#        [308.],
#        [323.],
#        [315.],
#        [307.],
#        [323.],
#        [304.],
#        [331.],
#        [316.],
#        [326.],
#        [320.],
#        [314.],
#        [315.],
#        [334.],
#        [299.],
#        [311.],
#        [318.],
#        [333.],
#        [327.],
#        [297.],
#        [317.],
#        [315.],
#        [322.],
#        [314.],
#        [329.],
#        [331.],
#        [330.],
#        [308.],
#        [315.],
#        [304.],
#        [312.],
#        [309.],
# ...

# %%
#predictions from the model
predictions = model.predict(X_test)
print('predicted GRE scores:',predictions,sep = '\n')
# Out:
# predicted GRE scores:
# [0.68922652 0.6791073  0.9523264  0.7195842  0.81065724 0.66898807
#  0.76006111 0.83089569 0.77018033 0.73982265 0.69934575 0.486842
#  0.83089569 0.83089569 0.77018033 0.80053801 0.61839194 0.68922652
#  0.87137259 0.70946498 0.6791073  0.66898807 0.84101492 0.53743813
#  0.81065724 0.70946498 0.87137259 0.63863039 0.79041879 0.70946498
#  0.62851117 0.79041879 0.59815349 0.87137259 0.7195842  0.82077646
#  0.76006111 0.69934575 0.70946498 0.90173027 0.54755736 0.66898807
#  0.73982265 0.89161105 0.83089569 0.52731891 0.72970343 0.70946498
#  0.78029956 0.69934575 0.85113414 0.87137259 0.86125337 0.63863039
#  0.70946498 0.59815349 0.6791073  0.64874962 0.74994188 0.73982265
#  0.54755736 0.74994188 0.80053801 0.86125337 0.9118495  0.63863039
#  0.76006111 0.80053801 0.96244563 0.73982265 0.60827272 0.70946498
#  0.82077646 0.65886885 0.94220718 0.59815349 0.88149182 0.79041879
#  0.76006111 0.69934575 0.83089569 0.45648432 0.9118495  0.83089569
# ...

# %%
Y_test
# Out:
# 304    0.62
# 340    0.75
# 47     0.89
# 67     0.57
# 479    0.79
# 485    0.70
# 310    0.76
# 31     0.74
# 249    0.77
# 90     0.64
# 322    0.72
# 168    0.64
# 119    0.71
# 66     0.61
# 305    0.74
# 189    0.88
# 434    0.64
# 289    0.79
# 142    0.92
# 146    0.75
# 293    0.64
# 312    0.78
# 311    0.84
# 492    0.53
# 65     0.55
# 374    0.39
# 34     0.94
# 342    0.58
# 173    0.89
# 201    0.72
#        ...
# 323    0.62
# 324    0.67
# 147    0.83
# 29     0.54
# 107    0.91
# 463    0.57
# 495    0.87
# 425    0.92
# 250    0.74
# 135    0.82
# 260    0.87
# 117    0.45
# 187    0.93
# 415    0.76
# 165    0.78
# 223    0.71
# 444    0.92
# 285    0.93
# 491    0.54
# 476    0.62
# 477    0.65
# 480    0.80
# 417    0.52
# 6      0.75
# 422    0.73
# 11     0.84
# 192    0.86
# 92     0.34
# 221    0.75
# 110    0.61
# Name: Chance of Admit , Length: 100, dtype: float64

# %% [markdown]
# # Scatter the plot between the predictions and assumed data

# %%
plt.scatter(Y_test,predictions)

# %% [markdown]
# # TOEFL SCORE - CHANCE OF ADMIT

# %%
X = df1['TOEFL Score']
Y = df2['Chance of Admit ']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2,random_state = 1)

# %%
X_train
# Out:
# 238    104.0
# 438    110.0
# 475    101.0
# 58      99.0
# 380    104.0
# 78      95.0
# 379     99.0
# 247    104.0
# 207    102.0
# 101    105.0
# 344     96.0
# 392    112.0
# 423    119.0
# 488    112.0
# 256     99.0
# 180    104.0
# 436    110.0
# 18     110.0
# 40     110.0
# 421    112.0
# 469    114.0
# 41     105.0
# 159    100.0
# 286    118.0
# 132    105.0
# 290    105.0
# 496    117.0
# 341    110.0
# 80     105.0
# 46     114.0
#        ...
# 68     109.0
# 50      98.0
# 398    103.0
# 413    101.0
# 156    105.0
# 252    100.0
# 395    110.0
# 468    110.0
# 402    109.0
# 357    104.0
# 254    114.0
# 276    113.0
# 178    108.0
# 281    110.0
# 390    102.0
# 237    114.0
# 71     112.0
# 460    105.0
# 129    118.0
# 144    112.0
# 448    109.0
# 335    111.0
# 133    112.0
# 203    120.0
# 393    104.0
# 255    110.0
# 72     111.0
# 396    107.0
# 235    111.0
# 37     105.0
# Name: TOEFL Score, Length: 400, dtype: float64

# %%
Y_train
# Out:
# 238    0.70
# 438    0.67
# 475    0.59
# 58     0.36
# 380    0.78
# 78     0.44
# 379    0.71
# 247    0.71
# 207    0.66
# 101    0.64
# 344    0.47
# 392    0.84
# 423    0.94
# 488    0.76
# 256    0.76
# 180    0.71
# 436    0.58
# 18     0.63
# 40     0.46
# 421    0.77
# 469    0.86
# 41     0.49
# 159    0.52
# 286    0.92
# 132    0.71
# 290    0.58
# 496    0.96
# 341    0.79
# 80     0.50
# 46     0.86
#        ...
# 68     0.68
# 50     0.76
# 398    0.67
# 413    0.49
# 156    0.70
# 252    0.71
# 395    0.82
# 468    0.81
# 402    0.78
# 357    0.68
# 254    0.85
# 276    0.89
# 178    0.72
# 281    0.80
# 390    0.64
# 237    0.86
# 71     0.96
# 460    0.77
# 129    0.92
# 144    0.80
# 448    0.80
# 335    0.83
# 133    0.79
# 203    0.97
# 393    0.77
# 255    0.79
# 72     0.93
# 396    0.84
# 235    0.88
# 37     0.58
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
X_test
# Out:
# 304    106.0
# 340    107.0
# 47     119.0
# 67     107.0
# 479    110.0
# 485    101.0
# 310    104.0
# 31     103.0
# 249    111.0
# 90     106.0
# 322    107.0
# 168     97.0
# 119    104.0
# 66     114.0
# 305    109.0
# 189    112.0
# 434    103.0
# 289    109.0
# 142    115.0
# 146    105.0
# 293     98.0
# 312    107.0
# 311    108.0
# 492    101.0
# 65     112.0
# 374    105.0
# 34     112.0
# 342    106.0
# 173    113.0
# 201    110.0
#        ...
# 323    102.0
# 324    104.0
# 147    114.0
# 29      99.0
# 107    117.0
# 463    107.0
# 495    108.0
# 425    111.0
# 250    104.0
# 135    109.0
# 260    108.0
# 117    104.0
# 187    118.0
# 415    106.0
# 165    110.0
# 223    109.0
# 444    113.0
# 285    116.0
# 491     99.0
# 476    104.0
# 477    105.0
# 480    102.0
# 417    103.0
# 6      109.0
# 422    112.0
# 11     111.0
# 192    114.0
# 92      98.0
# 221    110.0
# 110    108.0
# Name: TOEFL Score, Length: 100, dtype: float64

# %%
Y_test
# Out:
# 304    0.62
# 340    0.75
# 47     0.89
# 67     0.57
# 479    0.79
# 485    0.70
# 310    0.76
# 31     0.74
# 249    0.77
# 90     0.64
# 322    0.72
# 168    0.64
# 119    0.71
# 66     0.61
# 305    0.74
# 189    0.88
# 434    0.64
# 289    0.79
# 142    0.92
# 146    0.75
# 293    0.64
# 312    0.78
# 311    0.84
# 492    0.53
# 65     0.55
# 374    0.39
# 34     0.94
# 342    0.58
# 173    0.89
# 201    0.72
#        ...
# 323    0.62
# 324    0.67
# 147    0.83
# 29     0.54
# 107    0.91
# 463    0.57
# 495    0.87
# 425    0.92
# 250    0.74
# 135    0.82
# 260    0.87
# 117    0.45
# 187    0.93
# 415    0.76
# 165    0.78
# 223    0.71
# 444    0.92
# 285    0.93
# 491    0.54
# 476    0.62
# 477    0.65
# 480    0.80
# 417    0.52
# 6      0.75
# 422    0.73
# 11     0.84
# 192    0.86
# 92     0.34
# 221    0.75
# 110    0.61
# Name: Chance of Admit , Length: 100, dtype: float64

# %% [markdown]
# # linear regression with sklearn

# %%
X_train = X_train.values.reshape((-1,1))
X_train
# Out:
# array([[104.],
#        [110.],
#        [101.],
#        [ 99.],
#        [104.],
#        [ 95.],
#        [ 99.],
#        [104.],
#        [102.],
#        [105.],
#        [ 96.],
#        [112.],
#        [119.],
#        [112.],
#        [ 99.],
#        [104.],
#        [110.],
#        [110.],
#        [110.],
#        [112.],
#        [114.],
#        [105.],
#        [100.],
#        [118.],
#        [105.],
#        [105.],
#        [117.],
#        [110.],
#        [105.],
#        [114.],
#        [100.],
#        [ 97.],
#        [118.],
#        [120.],
#        [119.],
#        [116.],
#        [113.],
#        [105.],
#        [101.],
#        [ 99.],
#        [109.],
#        [111.],
#        [107.],
#        [102.],
#        [105.],
#        [105.],
#        [106.],
#        [100.],
#        [106.],
#        [119.],
#        [109.],
#        [101.],
#        [114.],
#        [108.],
#        [110.],
#        [102.],
#        [115.],
#        [110.],
# ...

# %%
from sklearn import linear_model as lm
model = lm.LinearRegression()
results = model.fit(X_train,Y_train)

# %% [markdown]
# # accuracy

# %%
accuracy = model.score(X_train,Y_train)
print('Accuracy of the model:',accuracy)
# Out:
# Accuracy of the model: 0.6481119070068649

# %% [markdown]
# # Print coefficients

# %%
print('intercept',model.intercept_)
print('slope:',model.coef_)
# Out:
# intercept -1.2509581302623105
# slope: [0.01839143]

# %%
X_test = X_test.values.reshape((-1,1))
X_test
# Out:
# array([[106.],
#        [107.],
#        [119.],
#        [107.],
#        [110.],
#        [101.],
#        [104.],
#        [103.],
#        [111.],
#        [106.],
#        [107.],
#        [ 97.],
#        [104.],
#        [114.],
#        [109.],
#        [112.],
#        [103.],
#        [109.],
#        [115.],
#        [105.],
#        [ 98.],
#        [107.],
#        [108.],
#        [101.],
#        [112.],
#        [105.],
#        [112.],
#        [106.],
#        [113.],
#        [110.],
#        [102.],
#        [110.],
#        [100.],
#        [116.],
#        [ 98.],
#        [112.],
#        [101.],
#        [103.],
#        [105.],
#        [116.],
#        [100.],
#        [104.],
#        [101.],
#        [119.],
#        [113.],
#        [ 96.],
#        [100.],
#        [104.],
#        [103.],
#        [106.],
#        [111.],
#        [117.],
#        [115.],
#        [102.],
#        [101.],
#        [105.],
#        [107.],
#        [106.],
# ...

# %%
#predictions from the model
predictions = model.predict(X_test)
print('predicted O.ring.failures:',predictions,sep = '\n')
# Out:
# predicted O.ring.failures:
# [0.69853343 0.71692486 0.93762202 0.71692486 0.77209915 0.60657628
#  0.66175057 0.64335914 0.79049058 0.69853343 0.71692486 0.53301057
#  0.66175057 0.84566487 0.75370772 0.80888201 0.64335914 0.75370772
#  0.8640563  0.680142   0.551402   0.71692486 0.73531629 0.60657628
#  0.80888201 0.680142   0.80888201 0.69853343 0.82727344 0.77209915
#  0.62496771 0.77209915 0.58818486 0.88244773 0.551402   0.80888201
#  0.60657628 0.64335914 0.680142   0.88244773 0.58818486 0.66175057
#  0.60657628 0.93762202 0.82727344 0.51461914 0.58818486 0.66175057
#  0.64335914 0.69853343 0.79049058 0.90083916 0.8640563  0.62496771
#  0.60657628 0.680142   0.71692486 0.69853343 0.69853343 0.71692486
#  0.47783628 0.64335914 0.58818486 0.84566487 0.90083916 0.66175057
#  0.73531629 0.71692486 0.80888201 0.75370772 0.62496771 0.66175057
#  0.84566487 0.56979343 0.90083916 0.71692486 0.73531629 0.79049058
#  0.66175057 0.75370772 0.73531629 0.66175057 0.91923059 0.69853343
# ...

# %% [markdown]
# # Scatter the plot between the predictions and assumed data

# %%
plt.scatter(Y_test,predictions)

# %% [markdown]
# # sop - chance to admit

# %%
X = df1['SOP']
Y = df2['Chance of Admit ']

# %% [markdown]
# # Split the data into Training set and Test set(80% - 20%)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2,random_state = 1)

# %%
X_train,X_test,Y_train,Y_test
# Out:
# (238    2.0
#  438    2.5
#  475    3.5
#  58     3.0
#  380    3.5
#  78     3.0
#  379    2.5
#  247    2.5
#  207    3.5
#  101    2.5
#  344    1.5
#  392    4.0
#  423    4.5
#  488    3.0
#  256    4.0
#  180    3.5
#  436    1.5
#  18     4.0
#  40     3.5
#  421    3.0
#  469    4.0
#  41     2.5
#  159    1.5
#  286    4.5
#  132    3.5
#  290    2.5
#  496    5.0
#  341    3.5
#  80     2.0
#  46     4.0
#        ...
#  68     3.5
#  50     2.5
#  398    3.5
#  413    3.0
#  156    2.0
#  252    2.5
#  395    3.5
#  468    4.0
#  402    3.5
#  357    3.5
#  254    4.0
#  276    5.0
#  178    2.5
#  281    4.0
#  390    2.0
#  237    4.5
#  71     5.0
#  460    4.0
#  129    5.0
#  144    3.0
#  448    2.5
#  335    4.0
#  133    4.0
#  203    4.0
#  393    3.0
#  255    4.0
#  72     5.0
#  396    3.0
#  235    4.5
#  37     1.0
#  Name: SOP, Length: 400, dtype: float64, 304    2.5
#  340    3.0
#  47     4.5
#  67     3.5
#  479    4.5
#  485    2.5
#  310    3.0
# ...

# %% [markdown]
# # linear regression with sklearn

# %%
X_train = X_train.values.reshape((-1,1))
X_train
# Out:
# array([[2. ],
#        [2.5],
#        [3.5],
#        [3. ],
#        [3.5],
#        [3. ],
#        [2.5],
#        [2.5],
#        [3.5],
#        [2.5],
#        [1.5],
#        [4. ],
#        [4.5],
#        [3. ],
#        [4. ],
#        [3.5],
#        [1.5],
#        [4. ],
#        [3.5],
#        [3. ],
#        [4. ],
#        [2.5],
#        [1.5],
#        [4.5],
#        [3.5],
#        [2.5],
#        [5. ],
#        [3.5],
#        [2. ],
#        [4. ],
#        [2. ],
#        [3. ],
#        [5. ],
#        [5. ],
#        [4.5],
#        [3.5],
#        [4.5],
#        [3. ],
#        [2. ],
#        [2.5],
#        [3.5],
#        [4.5],
#        [2.5],
#        [1.5],
#        [3.5],
#        [3. ],
#        [3.5],
#        [1.5],
#        [1.5],
#        [5. ],
#        [4. ],
#        [4. ],
#        [4.5],
#        [4. ],
#        [4. ],
#        [5. ],
#        [3.5],
#        [4. ],
#        [5. ],
#        [1. ],
#        [2.5],
#        [3.5],
# ...

# %%
from sklearn import linear_model as lm
model = lm.LinearRegression()
results = model.fit(X_train,Y_train)

# %%
accuracy = model.score(X_train,Y_train)
print('Accuracy of the model:',accuracy)
# Out:
# Accuracy of the model: 0.46714293198861456

# %%
print('intercept',model.intercept_)
print('slope:',model.coef_)
# Out:
# intercept 0.40094873475730036
# slope: [0.09530194]

# %%
X_test = X_test.values.reshape((-1,1))
X_test
# Out:
# array([[2.5],
#        [3. ],
#        [4.5],
#        [3.5],
#        [4.5],
#        [2.5],
#        [3. ],
#        [4. ],
#        [3.5],
#        [4. ],
#        [2.5],
#        [2. ],
#        [3. ],
#        [3. ],
#        [3.5],
#        [5. ],
#        [3.5],
#        [4. ],
#        [4. ],
#        [2. ],
#        [3.5],
#        [4.5],
#        [4.5],
#        [2.5],
#        [3.5],
#        [2. ],
#        [4. ],
#        [3. ],
#        [4. ],
#        [3.5],
#        [3. ],
#        [4. ],
#        [2.5],
#        [4.5],
#        [1.5],
#        [3.5],
#        [2.5],
#        [2. ],
#        [3. ],
#        [4. ],
#        [2. ],
#        [4. ],
#        [3.5],
#        [5. ],
#        [3.5],
#        [2.5],
#        [3. ],
#        [4. ],
#        [3. ],
#        [4. ],
#        [4.5],
#        [4.5],
#        [4.5],
#        [2. ],
#        [3.5],
#        [3. ],
#        [4.5],
#        [2.5],
#        [4. ],
#        [3. ],
#        [1. ],
#        [4.5],
# ...

# %%
#predictions from the model
predictions = model.predict(X_test)
print('predicted O.ring.failures:',predictions,sep = '\n')
# Out:
# predicted O.ring.failures:
# [0.63920359 0.68685456 0.82980747 0.73450553 0.82980747 0.63920359
#  0.68685456 0.7821565  0.73450553 0.7821565  0.63920359 0.59155262
#  0.68685456 0.68685456 0.73450553 0.87745844 0.73450553 0.7821565
#  0.7821565  0.59155262 0.73450553 0.82980747 0.82980747 0.63920359
#  0.73450553 0.59155262 0.7821565  0.68685456 0.7821565  0.73450553
#  0.68685456 0.7821565  0.63920359 0.82980747 0.54390165 0.73450553
#  0.63920359 0.59155262 0.68685456 0.7821565  0.59155262 0.7821565
#  0.73450553 0.87745844 0.73450553 0.63920359 0.68685456 0.7821565
#  0.68685456 0.7821565  0.82980747 0.82980747 0.82980747 0.59155262
#  0.73450553 0.68685456 0.82980747 0.63920359 0.7821565  0.68685456
#  0.49625068 0.82980747 0.7821565  0.82980747 0.87745844 0.63920359
#  0.73450553 0.73450553 0.87745844 0.68685456 0.59155262 0.68685456
#  0.68685456 0.54390165 0.73450553 0.73450553 0.82980747 0.7821565
#  0.68685456 0.73450553 0.87745844 0.59155262 0.82980747 0.7821565
# ...

# %% [markdown]
# # Scatter the plot between the predictions and assumed data

# %%
plt.scatter(Y_test,predictions)

# %% [markdown]
# # lor - chance of regression

# %%
X = df1['LOR ']
Y = df2['Chance of Admit ']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2,random_state = 1)

# %%
X_train,X_test,Y_train,Y_test
# Out:
# (238    3.5
#  438    3.5
#  475    2.5
#  58     2.0
#  380    4.0
#  78     2.0
#  379    3.0
#  247    3.5
#  207    4.0
#  101    3.0
#  344    2.0
#  392    3.5
#  423    5.0
#  488    4.0
#  256    4.0
#  180    3.0
#  436    4.0
#  18     3.0
#  40     3.0
#  421    4.5
#  469    3.5
#  41     2.5
#  159    2.0
#  286    4.0
#  132    3.5
#  290    3.0
#  496    5.0
#  341    3.5
#  80     3.0
#  46     5.0
#        ...
#  68     4.0
#  50     4.5
#  398    4.0
#  413    2.0
#  156    2.5
#  252    3.5
#  395    3.5
#  468    5.0
#  402    3.0
#  357    3.5
#  254    5.0
#  276    4.5
#  178    3.0
#  281    4.5
#  390    2.5
#  237    5.0
#  71     5.0
#  460    4.5
#  129    5.0
#  144    3.5
#  448    4.0
#  335    4.5
#  133    4.5
#  203    5.0
#  393    3.0
#  255    4.5
#  72     5.0
#  396    3.5
#  235    4.0
#  37     2.0
#  Name: LOR , Length: 400, dtype: float64, 304    2.0
#  340    3.0
#  47     4.0
#  67     3.5
#  479    4.0
#  485    3.5
#  310    3.5
# ...

# %% [markdown]
# # linear regression with sklearn

# %%
X_train = X_train.values.reshape((-1,1))
X_train
# Out:
# array([[3.5],
#        [3.5],
#        [2.5],
#        [2. ],
#        [4. ],
#        [2. ],
#        [3. ],
#        [3.5],
#        [4. ],
#        [3. ],
#        [2. ],
#        [3.5],
#        [5. ],
#        [4. ],
#        [4. ],
#        [3. ],
#        [4. ],
#        [3. ],
#        [3. ],
#        [4.5],
#        [3.5],
#        [2.5],
#        [2. ],
#        [4. ],
#        [3.5],
#        [3. ],
#        [5. ],
#        [3.5],
#        [3. ],
#        [5. ],
#        [2. ],
#        [3. ],
#        [5. ],
#        [5. ],
#        [4. ],
#        [4. ],
#        [4.5],
#        [3.5],
#        [2.5],
#        [2.5],
#        [3.5],
#        [4.5],
#        [3.5],
#        [2. ],
#        [4. ],
#        [2. ],
#        [2.5],
#        [2.5],
#        [2.5],
#        [4.5],
#        [3. ],
#        [3. ],
#        [4.5],
#        [3.5],
#        [5. ],
#        [5. ],
#        [3. ],
#        [5. ],
#        [4.5],
#        [2. ],
#        [4. ],
#        [4. ],
# ...

# %%
from sklearn import linear_model as lm
model = lm.LinearRegression()
results = model.fit(X_train,Y_train)

# %% [markdown]
# # accuracy

# %%
accuracy = model.score(X_train,Y_train)
print('Accuracy of the model:',accuracy)
# Out:
# Accuracy of the model: 0.41050880034388726

# %% [markdown]
# # Print coefficients

# %%
print('intercept',model.intercept_)
print('slope:',model.coef_)
# Out:
# intercept 0.3834007936014329
# slope: [0.09667718]

# %%
X_test = X_test.values.reshape((-1,1))
X_test
# Out:
# array([[2. ],
#        [3. ],
#        [4. ],
#        [3.5],
#        [4. ],
#        [3.5],
#        [3.5],
#        [4. ],
#        [4. ],
#        [4. ],
#        [4. ],
#        [4. ],
#        [3.5],
#        [3. ],
#        [3.5],
#        [5. ],
#        [3. ],
#        [3.5],
#        [3.5],
#        [2.5],
#        [3. ],
#        [4.5],
#        [4. ],
#        [4.5],
#        [3.5],
#        [2.5],
#        [5. ],
#        [3. ],
#        [4.5],
#        [3. ],
#        [3. ],
#        [3.5],
#        [3.5],
#        [4.5],
#        [2. ],
#        [3. ],
#        [3. ],
#        [3. ],
#        [3. ],
#        [3.5],
#        [2. ],
#        [3.5],
#        [5. ],
#        [4.5],
#        [3. ],
#        [1.5],
#        [2.5],
#        [2.5],
#        [2.5],
#        [3.5],
#        [4. ],
#        [5. ],
#        [3. ],
#        [3.5],
#        [4.5],
#        [3. ],
#        [4. ],
#        [2.5],
#        [3. ],
#        [3.5],
#        [1. ],
#        [3.5],
# ...

# %%
#predictions from the model
predictions = model.predict(X_test)
print('predicted O.ring.failures:',predictions,sep = '\n')
# Out:
# predicted O.ring.failures:
# [0.57675515 0.67343234 0.77010952 0.72177093 0.77010952 0.72177093
#  0.72177093 0.77010952 0.77010952 0.77010952 0.77010952 0.77010952
#  0.72177093 0.67343234 0.72177093 0.8667867  0.67343234 0.72177093
#  0.72177093 0.62509374 0.67343234 0.81844811 0.77010952 0.81844811
#  0.72177093 0.62509374 0.8667867  0.67343234 0.81844811 0.67343234
#  0.67343234 0.72177093 0.72177093 0.81844811 0.57675515 0.67343234
#  0.67343234 0.67343234 0.67343234 0.72177093 0.57675515 0.72177093
#  0.8667867  0.81844811 0.67343234 0.52841656 0.62509374 0.62509374
#  0.62509374 0.72177093 0.77010952 0.8667867  0.67343234 0.72177093
#  0.81844811 0.67343234 0.77010952 0.62509374 0.67343234 0.72177093
#  0.48007797 0.72177093 0.8667867  0.67343234 0.8667867  0.67343234
#  0.77010952 0.77010952 0.81844811 0.67343234 0.62509374 0.62509374
#  0.67343234 0.57675515 0.81844811 0.67343234 0.77010952 0.8667867
#  0.62509374 0.77010952 0.72177093 0.62509374 0.72177093 0.81844811
# ...

# %% [markdown]
# # Scatter the plot between the predictions and assumed data

# %%
plt.scatter(Y_test,predictions)

# %% [markdown]
# # multi linear

# %% [markdown]
# # sop,gre score,chance of admit

# %%
X =df1[["SOP","GRE Score"]]
Y = df2["Chance of Admit "]
model1 = sm.OLS(Y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Chance of Admit    R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                 1.469e+04
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):               0.00
# Time:                        13:56:26   Log-Likelihood:                 467.82
# No. Observations:                 500   AIC:                            -931.6
# Df Residuals:                     498   BIC:                            -923.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# SOP            0.0815      0.005     17.654      0.000       0.072       0.091
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2,random_state = 1)
X_train,X_test,Y_train,Y_test
# Out:
# (     SOP  GRE Score
#  238  2.0      310.0
#  438  2.5      318.0
#  475  3.5      300.0
#  58   3.0      300.0
#  380  3.5      322.0
#  78   3.0      296.0
#  379  2.5      311.0
#  247  2.5      311.0
#  207  3.5      310.0
#  101  2.5      312.0
#  344  1.5      295.0
#  392  4.0      326.0
#  423  4.5      334.0
#  488  3.0      322.0
#  256  4.0      309.0
#  180  3.5      300.0
#  436  1.5      310.0
#  18   4.0      318.0
#  40   3.5      308.0
#  421  3.0      321.0
#  469  4.0      326.0
#  41   2.5      316.0
#  159  1.5      297.0
#  286  4.5      336.0
#  132  3.5      309.0
#  290  2.5      307.0
#  496  5.0      337.0
#  341  3.5      326.0
#  80   2.0      312.0
#  46   4.0      329.0
#  ..   ...        ...
#  68   3.5      318.0
#  50   2.5      313.0
#  398  3.5      312.0
#  413  3.0      317.0
#  156  2.0      315.0
#  252  2.5      318.0
#  395  3.5      324.0
#  468  4.0      323.0
#  402  3.5      324.0
#  357  3.5      301.0
#  254  4.0      321.0
# ...

# %%
X_train = X_train.values.reshape((-1,2))
X_train = pd.DataFrame(X_train)

# %%
features = X_train.iloc[:,:].values
features
labels = Y_train.iloc[:].values
labels
# Out:
# array([0.7 , 0.67, 0.59, 0.36, 0.78, 0.44, 0.71, 0.71, 0.66, 0.64, 0.47,
#        0.84, 0.94, 0.76, 0.76, 0.71, 0.58, 0.63, 0.46, 0.77, 0.86, 0.49,
#        0.52, 0.92, 0.71, 0.58, 0.96, 0.79, 0.5 , 0.86, 0.51, 0.44, 0.93,
#        0.96, 0.95, 0.81, 0.89, 0.71, 0.38, 0.61, 0.78, 0.87, 0.69, 0.56,
#        0.69, 0.73, 0.73, 0.42, 0.57, 0.95, 0.62, 0.47, 0.9 , 0.48, 0.85,
#        0.77, 0.7 , 0.86, 0.9 , 0.56, 0.63, 0.73, 0.34, 0.8 , 0.71, 0.71,
#        0.78, 0.92, 0.69, 0.83, 0.44, 0.74, 0.49, 0.84, 0.89, 0.89, 0.53,
#        0.78, 0.84, 0.38, 0.72, 0.42, 0.56, 0.64, 0.72, 0.58, 0.42, 0.94,
#        0.78, 0.46, 0.67, 0.85, 0.84, 0.66, 0.65, 0.77, 0.84, 0.73, 0.73,
#        0.58, 0.79, 0.84, 0.59, 0.64, 0.64, 0.62, 0.77, 0.57, 0.87, 0.72,
#        0.87, 0.61, 0.91, 0.81, 0.61, 0.8 , 0.69, 0.56, 0.62, 0.45, 0.62,
#        0.66, 0.69, 0.92, 0.62, 0.69, 0.78, 0.63, 0.83, 0.71, 0.91, 0.94,
#        0.75, 0.49, 0.79, 0.52, 0.93, 0.61, 0.59, 0.68, 0.64, 0.72, 0.63,
# ...

# %%
X = features
Y = labels
from sklearn import linear_model as lm
model = lm.LinearRegression()
results = model.fit(X,Y)

# %%
predictions = model.predict(X)
accuracy = model.score(X,Y)
print("accuracy of the model:",accuracy)
# Out:
# accuracy of the model: 0.7233577191797154

# %% [markdown]
# # visualizing the predictions

# %%
#evaluating the model
from sklearn.metrics import mean_squared_error,r2_score
#printing values
print("slope:",model.coef_)
print("intercept:",model.intercept_)
print("\n")
# Out:
# slope: [0.04183647 0.00787301]
# intercept: -1.90845535532835

# %% [markdown]
# # SOP,TOEFL Score,Chance of Admit

# %%
X =df1[["SOP","TOEFL Score"]]
Y = df2["Chance of Admit "]
model1 = sm.OLS(Y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Chance of Admit    R-squared:                       0.985
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                 1.584e+04
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):               0.00
# Time:                        13:56:34   Log-Likelihood:                 486.26
# No. Observations:                 500   AIC:                            -968.5
# Df Residuals:                     498   BIC:                            -960.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# SOP             0.0722      0.005     15.478      0.000       0.063       0.081
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2,random_state = 1)
X_train,X_test,Y_train,Y_test
# Out:
# (     SOP  TOEFL Score
#  238  2.0        104.0
#  438  2.5        110.0
#  475  3.5        101.0
#  58   3.0         99.0
#  380  3.5        104.0
#  78   3.0         95.0
#  379  2.5         99.0
#  247  2.5        104.0
#  207  3.5        102.0
#  101  2.5        105.0
#  344  1.5         96.0
#  392  4.0        112.0
#  423  4.5        119.0
#  488  3.0        112.0
#  256  4.0         99.0
#  180  3.5        104.0
#  436  1.5        110.0
#  18   4.0        110.0
#  40   3.5        110.0
#  421  3.0        112.0
#  469  4.0        114.0
#  41   2.5        105.0
#  159  1.5        100.0
#  286  4.5        118.0
#  132  3.5        105.0
#  290  2.5        105.0
#  496  5.0        117.0
#  341  3.5        110.0
#  80   2.0        105.0
#  46   4.0        114.0
#  ..   ...          ...
#  68   3.5        109.0
#  50   2.5         98.0
#  398  3.5        103.0
#  413  3.0        101.0
#  156  2.0        105.0
#  252  2.5        100.0
#  395  3.5        110.0
#  468  4.0        110.0
# ...

# %%
X_train = X_train.values.reshape((-1,2))
X_train = pd.DataFrame(X_train)

# %%
features = X_train.iloc[:,:].values
features
labels = Y_train.iloc[:].values
labels
# Out:
# array([0.7 , 0.67, 0.59, 0.36, 0.78, 0.44, 0.71, 0.71, 0.66, 0.64, 0.47,
#        0.84, 0.94, 0.76, 0.76, 0.71, 0.58, 0.63, 0.46, 0.77, 0.86, 0.49,
#        0.52, 0.92, 0.71, 0.58, 0.96, 0.79, 0.5 , 0.86, 0.51, 0.44, 0.93,
#        0.96, 0.95, 0.81, 0.89, 0.71, 0.38, 0.61, 0.78, 0.87, 0.69, 0.56,
#        0.69, 0.73, 0.73, 0.42, 0.57, 0.95, 0.62, 0.47, 0.9 , 0.48, 0.85,
#        0.77, 0.7 , 0.86, 0.9 , 0.56, 0.63, 0.73, 0.34, 0.8 , 0.71, 0.71,
#        0.78, 0.92, 0.69, 0.83, 0.44, 0.74, 0.49, 0.84, 0.89, 0.89, 0.53,
#        0.78, 0.84, 0.38, 0.72, 0.42, 0.56, 0.64, 0.72, 0.58, 0.42, 0.94,
#        0.78, 0.46, 0.67, 0.85, 0.84, 0.66, 0.65, 0.77, 0.84, 0.73, 0.73,
#        0.58, 0.79, 0.84, 0.59, 0.64, 0.64, 0.62, 0.77, 0.57, 0.87, 0.72,
#        0.87, 0.61, 0.91, 0.81, 0.61, 0.8 , 0.69, 0.56, 0.62, 0.45, 0.62,
#        0.66, 0.69, 0.92, 0.62, 0.69, 0.78, 0.63, 0.83, 0.71, 0.91, 0.94,
#        0.75, 0.49, 0.79, 0.52, 0.93, 0.61, 0.59, 0.68, 0.64, 0.72, 0.63,
# ...

# %%
X = features
Y = labels
from sklearn import linear_model as lm
model = lm.LinearRegression()
results = model.fit(X,Y)

# %%
predictions = model.predict(X)
accuracy = model.score(X,Y)
print("accuracy of the model:",accuracy)
# Out:
# accuracy of the model: 0.6936083886089023

# %%
#evaluating the model
from sklearn.metrics import mean_squared_error,r2_score
#printing values
print("slope:",model.coef_)
print("intercept:",model.intercept_)
print("\n")
# Out:
# slope: [0.03900395 0.0142572 ]
# intercept: -0.9386522385154548

# %% [markdown]
# # LOR,TOEFL Score,Chance of Admit

# %%
X =df1[["LOR ","TOEFL Score"]]
Y = df2["Chance of Admit "]
model1 = sm.OLS(Y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Chance of Admit    R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                 1.494e+04
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):               0.00
# Time:                        13:56:41   Log-Likelihood:                 471.99
# No. Observations:                 500   AIC:                            -940.0
# Df Residuals:                     498   BIC:                            -931.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# LOR             0.0713      0.005     14.095      0.000       0.061       0.081
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2,random_state = 1)
X_train,X_test,Y_train,Y_test
# Out:
# (     LOR   TOEFL Score
#  238   3.5        104.0
#  438   3.5        110.0
#  475   2.5        101.0
#  58    2.0         99.0
#  380   4.0        104.0
#  78    2.0         95.0
#  379   3.0         99.0
#  247   3.5        104.0
#  207   4.0        102.0
#  101   3.0        105.0
#  344   2.0         96.0
#  392   3.5        112.0
#  423   5.0        119.0
#  488   4.0        112.0
#  256   4.0         99.0
#  180   3.0        104.0
#  436   4.0        110.0
#  18    3.0        110.0
#  40    3.0        110.0
#  421   4.5        112.0
#  469   3.5        114.0
#  41    2.5        105.0
#  159   2.0        100.0
#  286   4.0        118.0
#  132   3.5        105.0
#  290   3.0        105.0
#  496   5.0        117.0
#  341   3.5        110.0
#  80    3.0        105.0
#  46    5.0        114.0
#  ..    ...          ...
#  68    4.0        109.0
#  50    4.5         98.0
#  398   4.0        103.0
#  413   2.0        101.0
#  156   2.5        105.0
#  252   3.5        100.0
# ...

# %%
X_train = X_train.values.reshape((-1,2))
X_train = pd.DataFrame(X_train)

# %%
features = X_train.iloc[:,:].values
features
labels = Y_train.iloc[:].values
labels
# Out:
# array([0.7 , 0.67, 0.59, 0.36, 0.78, 0.44, 0.71, 0.71, 0.66, 0.64, 0.47,
#        0.84, 0.94, 0.76, 0.76, 0.71, 0.58, 0.63, 0.46, 0.77, 0.86, 0.49,
#        0.52, 0.92, 0.71, 0.58, 0.96, 0.79, 0.5 , 0.86, 0.51, 0.44, 0.93,
#        0.96, 0.95, 0.81, 0.89, 0.71, 0.38, 0.61, 0.78, 0.87, 0.69, 0.56,
#        0.69, 0.73, 0.73, 0.42, 0.57, 0.95, 0.62, 0.47, 0.9 , 0.48, 0.85,
#        0.77, 0.7 , 0.86, 0.9 , 0.56, 0.63, 0.73, 0.34, 0.8 , 0.71, 0.71,
#        0.78, 0.92, 0.69, 0.83, 0.44, 0.74, 0.49, 0.84, 0.89, 0.89, 0.53,
#        0.78, 0.84, 0.38, 0.72, 0.42, 0.56, 0.64, 0.72, 0.58, 0.42, 0.94,
#        0.78, 0.46, 0.67, 0.85, 0.84, 0.66, 0.65, 0.77, 0.84, 0.73, 0.73,
#        0.58, 0.79, 0.84, 0.59, 0.64, 0.64, 0.62, 0.77, 0.57, 0.87, 0.72,
#        0.87, 0.61, 0.91, 0.81, 0.61, 0.8 , 0.69, 0.56, 0.62, 0.45, 0.62,
#        0.66, 0.69, 0.92, 0.62, 0.69, 0.78, 0.63, 0.83, 0.71, 0.91, 0.94,
#        0.75, 0.49, 0.79, 0.52, 0.93, 0.61, 0.59, 0.68, 0.64, 0.72, 0.63,
# ...

# %%
X = features
Y = labels
from sklearn import linear_model as lm
model = lm.LinearRegression()
results = model.fit(X,Y)

# %%
predictions = model.predict(X)
accuracy = model.score(X,Y)
print("accuracy of the model:",accuracy)
# Out:
# accuracy of the model: 0.7013642567588092

# %%
#evaluating the model
from sklearn.metrics import mean_squared_error,r2_score
#printing values
print("slope:",model.coef_)
print("intercept:",model.intercept_)
print("\n")
# Out:
# slope: [0.04195973 0.01484669]
# intercept: -1.0173918450271637

# %% [markdown]
# # multi linear with 3 inputs

# %%
X =df1[["LOR ","TOEFL Score","GRE Score"]]
Y = df2["Chance of Admit "]
model1 = sm.OLS(Y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Chance of Admit    R-squared:                       0.985
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                 1.054e+04
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):               0.00
# Time:                        13:56:47   Log-Likelihood:                 486.30
# No. Observations:                 500   AIC:                            -966.6
# Df Residuals:                     497   BIC:                            -954.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# LOR             0.0658      0.005     13.096      0.000       0.056       0.076
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2,random_state = 1)
X_train,X_test,Y_train,Y_test
# Out:
# (     LOR   TOEFL Score  GRE Score
#  238   3.5        104.0      310.0
#  438   3.5        110.0      318.0
#  475   2.5        101.0      300.0
#  58    2.0         99.0      300.0
#  380   4.0        104.0      322.0
#  78    2.0         95.0      296.0
#  379   3.0         99.0      311.0
#  247   3.5        104.0      311.0
#  207   4.0        102.0      310.0
#  101   3.0        105.0      312.0
#  344   2.0         96.0      295.0
#  392   3.5        112.0      326.0
#  423   5.0        119.0      334.0
#  488   4.0        112.0      322.0
#  256   4.0         99.0      309.0
#  180   3.0        104.0      300.0
#  436   4.0        110.0      310.0
#  18    3.0        110.0      318.0
#  40    3.0        110.0      308.0
#  421   4.5        112.0      321.0
#  469   3.5        114.0      326.0
#  41    2.5        105.0      316.0
#  159   2.0        100.0      297.0
#  286   4.0        118.0      336.0
#  132   3.5        105.0      309.0
#  290   3.0        105.0      307.0
# ...

# %%
X_train = X_train.values.reshape((-1,3))
X_train = pd.DataFrame(X_train)

# %%
features = X_train.iloc[:,:].values
features
labels = Y_train.iloc[:].values
labels
# Out:
# array([0.7 , 0.67, 0.59, 0.36, 0.78, 0.44, 0.71, 0.71, 0.66, 0.64, 0.47,
#        0.84, 0.94, 0.76, 0.76, 0.71, 0.58, 0.63, 0.46, 0.77, 0.86, 0.49,
#        0.52, 0.92, 0.71, 0.58, 0.96, 0.79, 0.5 , 0.86, 0.51, 0.44, 0.93,
#        0.96, 0.95, 0.81, 0.89, 0.71, 0.38, 0.61, 0.78, 0.87, 0.69, 0.56,
#        0.69, 0.73, 0.73, 0.42, 0.57, 0.95, 0.62, 0.47, 0.9 , 0.48, 0.85,
#        0.77, 0.7 , 0.86, 0.9 , 0.56, 0.63, 0.73, 0.34, 0.8 , 0.71, 0.71,
#        0.78, 0.92, 0.69, 0.83, 0.44, 0.74, 0.49, 0.84, 0.89, 0.89, 0.53,
#        0.78, 0.84, 0.38, 0.72, 0.42, 0.56, 0.64, 0.72, 0.58, 0.42, 0.94,
#        0.78, 0.46, 0.67, 0.85, 0.84, 0.66, 0.65, 0.77, 0.84, 0.73, 0.73,
#        0.58, 0.79, 0.84, 0.59, 0.64, 0.64, 0.62, 0.77, 0.57, 0.87, 0.72,
#        0.87, 0.61, 0.91, 0.81, 0.61, 0.8 , 0.69, 0.56, 0.62, 0.45, 0.62,
#        0.66, 0.69, 0.92, 0.62, 0.69, 0.78, 0.63, 0.83, 0.71, 0.91, 0.94,
#        0.75, 0.49, 0.79, 0.52, 0.93, 0.61, 0.59, 0.68, 0.64, 0.72, 0.63,
# ...

# %%
X = features
Y = labels
from sklearn import linear_model as lm
model = lm.LinearRegression()
results = model.fit(X,Y)

# %%
predictions = model.predict(X)
accuracy = model.score(X,Y)
print("accuracy of the model:",accuracy)
# Out:
# accuracy of the model: 0.7513483168858937

# %%
#evaluating the model
from sklearn.metrics import mean_squared_error,r2_score
#printing values
print("slope:",model.coef_)
print("intercept:",model.intercept_)
print("\n")
# Out:
# slope: [0.0361488  0.00717702 0.00523974]
# intercept: -1.831233098975108

# %% [markdown]
# # multi linear with another 3 inputs

# %%
X =df1[["SOP","TOEFL Score","GRE Score"]]
Y = df2["Chance of Admit "]
model1 = sm.OLS(Y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Chance of Admit    R-squared:                       0.985
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                 1.082e+04
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):               0.00
# Time:                        13:56:52   Log-Likelihood:                 492.76
# No. Observations:                 500   AIC:                            -979.5
# Df Residuals:                     497   BIC:                            -966.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# SOP             0.0667      0.005     13.748      0.000       0.057       0.076
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size =0.2,random_state = 1)
X_train,X_test,Y_train,Y_test
# Out:
# (     SOP  TOEFL Score  GRE Score
#  238  2.0        104.0      310.0
#  438  2.5        110.0      318.0
#  475  3.5        101.0      300.0
#  58   3.0         99.0      300.0
#  380  3.5        104.0      322.0
#  78   3.0         95.0      296.0
#  379  2.5         99.0      311.0
#  247  2.5        104.0      311.0
#  207  3.5        102.0      310.0
#  101  2.5        105.0      312.0
#  344  1.5         96.0      295.0
#  392  4.0        112.0      326.0
#  423  4.5        119.0      334.0
#  488  3.0        112.0      322.0
#  256  4.0         99.0      309.0
#  180  3.5        104.0      300.0
#  436  1.5        110.0      310.0
#  18   4.0        110.0      318.0
#  40   3.5        110.0      308.0
#  421  3.0        112.0      321.0
#  469  4.0        114.0      326.0
#  41   2.5        105.0      316.0
#  159  1.5        100.0      297.0
#  286  4.5        118.0      336.0
#  132  3.5        105.0      309.0
#  290  2.5        105.0      307.0
# ...

# %%
X_train = X_train.values.reshape((-1,3))
X_train = pd.DataFrame(X_train)

# %%
predictions = model.predict(X)
accuracy = model.score(X,Y)
print("accuracy of the model:",accuracy)
# Out:
# accuracy of the model: 0.7340990860146388

# %%
#evaluating the model
from sklearn.metrics import mean_squared_error,r2_score
#printing values
print("slope:",model.coef_)
print("intercept:",model.intercept_)
print("\n")
# Out:
# slope: [0.0361488  0.00717702 0.00523974]
# intercept: -1.831233098975108
